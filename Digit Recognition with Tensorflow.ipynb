# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = tf.keras.utils.normalize(x_train,axis=1)
x_test = tf.keras.utils.normalize(x_test,axis=1)

# %%
model = Sequential()
 
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(Dense(128,activation=tf.nn.relu))
model.add(Dense(128,activation=tf.nn.relu))
model.add(Dense(10,activation=tf.nn.softmax))
 
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train,y_train,epochs=25)
# Out:
# Epoch 1/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2619 - accuracy: 0.9233
# Epoch 2/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1071 - accuracy: 0.9666
# Epoch 3/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0738 - accuracy: 0.9767
# Epoch 4/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0538 - accuracy: 0.9832
# Epoch 5/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0413 - accuracy: 0.9862
# Epoch 6/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0320 - accuracy: 0.9897
# Epoch 7/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0254 - accuracy: 0.9914
# Epoch 8/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0202 - accuracy: 0.9932
# Epoch 9/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0194 - accuracy: 0.9934
# Epoch 10/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0154 - accuracy: 0.9943
# Epoch 11/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0145 - accuracy: 0.9951
# Epoch 12/25
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0122 - accuracy: 0.9957
# Epoch 13/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0134 - accuracy: 0.9957
# Epoch 14/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0111 - accuracy: 0.9963
# Epoch 15/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0096 - accuracy: 0.9965
# Epoch 16/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0094 - accuracy: 0.9967
# Epoch 17/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0081 - accuracy: 0.9973
# Epoch 18/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0099 - accuracy: 0.9968
# Epoch 19/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0088 - accuracy: 0.9970
# Epoch 20/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0072 - accuracy: 0.9977
# Epoch 21/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0074 - accuracy: 0.9973
# Epoch 22/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0077 - accuracy: 0.9972
# Epoch 23/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0069 - accuracy: 0.9977
# Epoch 24/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0067 - accuracy: 0.9979
# Epoch 25/25
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0062 - accuracy: 0.9978

# %%
# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(x_test, y_test)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1666 - accuracy: 0.9733
# Test Loss: 0.16664016246795654
# Test Accuracy: 0.9732999801635742

# %%
predictions = model.predict(x_test)
for i in range(20):
    predicted_label = np.argmax(predictions[i])
    true_label = y_test[i]
    
    print("Predicted Label:", predicted_label)
    print("True Label:", true_label)
    plt.imshow(x_test[i], cmap='gray')
    plt.axis('off')
    plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step
# Predicted Label: 7
# True Label: 7
# Predicted Label: 2
# True Label: 2
# Predicted Label: 1
# True Label: 1
# Predicted Label: 0
# True Label: 0
# Predicted Label: 4
# True Label: 4
# Predicted Label: 1
# True Label: 1
# Predicted Label: 4
# True Label: 4
# Predicted Label: 9
# True Label: 9
# Predicted Label: 5
# True Label: 5
# Predicted Label: 9
# True Label: 9
# Predicted Label: 0
# True Label: 0
# Predicted Label: 6
# True Label: 6
# Predicted Label: 9
# True Label: 9
# Predicted Label: 0
# True Label: 0
# Predicted Label: 1
# True Label: 1
# Predicted Label: 5
# True Label: 5
# Predicted Label: 9
# True Label: 9
# Predicted Label: 7
# True Label: 7
# Predicted Label: 3
# True Label: 3
# Predicted Label: 4
# True Label: 4
